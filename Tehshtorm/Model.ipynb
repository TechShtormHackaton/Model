# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import einops
import numpy as np
import remotezip as rz
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
import keras
from keras import layers
import os
from Transform import *

# %%
model = tf.keras.models.load_model('video_model.keras', custom_objects={'Conv2Plus1D': Conv2Plus1D,
                'ResidualMain': ResidualMain,
                 'Project': Project,
                  'add_residual_block': add_residual_block,
                  'ResizeVideo': ResizeVideo})
# Out:
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'conv2_plus1d_9', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'resize_video_4', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'residual_main_4', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'resize_video_5', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'project_3', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'residual_main_5', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'resize_video_6', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'project_4', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'residual_main_6', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'resize_video_7', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'project_5', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\bgre4\venv\lib\site-packages\keras\src\layers\layer.py:360: UserWarning: `build()` was called on layer 'residual_main_7', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\bgre4\venv\lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.

    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

def frames_from_video_file(video_path, n_frames, output_size = (224,224), frame_step = 15):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))  

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

class FrameGenerator:
  
  """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
  
  def __init__(self, path, n_frames, training = False):
    
    self.path = path
    self.n_frames = n_frames
    self.training = training
      
  def __call__(self):
      
    for i, video_class in enumerate(os.listdir(self.path)):
      for item in os.listdir(f'{self.path}/{video_class}'):
        print(item)
        video_frames = frames_from_video_file(f'{self.path}/{video_class}/{item}', self.n_frames)
        label = i
        yield video_frames, label

# %%
n_frames = 10
batch_size = 8

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_ds = tf.data.Dataset.from_generator(FrameGenerator('data(1)', n_frames, training=True),
                                          output_signature = output_signature)


# Batch the data
train_ds = train_ds.batch(batch_size)

val_ds = tf.data.Dataset.from_generator(FrameGenerator('data(1)', n_frames),
                                        output_signature = output_signature)
val_ds = val_ds.batch(batch_size)

#test_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['test'], n_frames),
                                         #output_signature = output_signature)

#test_ds = test_ds.batch(batch_size)

# %%
HEIGHT = 224
WIDTH = 224

# %%
@keras.saving.register_keras_serializable()
class Conv2Plus1D(keras.layers.Layer):
  def __init__(self, filters, kernel_size, padding, **kwargs):
    """
      A sequence of convolutional layers that first apply the convolution operation over the
      spatial dimensions, and then the temporal dimension. 
    """
    super().__init__(**kwargs)
    self.seq = keras.Sequential([  
        # Spatial decomposition
        layers.Conv3D(filters=filters,
                      kernel_size=(1, kernel_size[1], kernel_size[2]),
                      padding=padding),
        # Temporal decomposition
        layers.Conv3D(filters=filters, 
                      kernel_size=(kernel_size[0], 1, 1),
                      padding=padding)
        ])

  def call(self, x):
    return self.seq(x)

# %%
@keras.saving.register_keras_serializable()
class ResidualMain(keras.layers.Layer):
  """
    Residual block of the model with convolution, layer normalization, and the
    activation function, ReLU.
  """
  def __init__(self, filters, kernel_size, **kwargs):
    super().__init__(**kwargs)
    self.seq = keras.Sequential([
        Conv2Plus1D(filters=filters,
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization(),
        layers.ReLU(),
        Conv2Plus1D(filters=filters, 
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
@keras.saving.register_keras_serializable()
class Project(keras.layers.Layer):
  """
    Project certain dimensions of the tensor as the data is passed through different 
    sized filters and downsampled. 
  """
  def __init__(self, units, **kwargs):
    super().__init__(**kwargs)
    self.seq = keras.Sequential([
        layers.Dense(units),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %%
@keras.saving.register_keras_serializable()
def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(filters, 
                     kernel_size)(input)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(out.shape[-1])(res)

  return layers.add([res, out])

# %%
@keras.saving.register_keras_serializable()
class ResizeVideo(keras.layers.Layer):
  def __init__(self, height, width, **kwargs):
    super().__init__(**kwargs)
    self.height = height
    self.width = width
    self.resizing_layer = layers.Resizing(self.height, self.width)

  def call(self, video):
    """
      Use the einops library to resize the tensor.  

      Args:
        video: Tensor representation of the video, in the form of a set of frames.

      Return:
        A downsampled size of the video according to the new height and width it should be resized to.
    """
    # b stands for batch size, t stands for time, h stands for height, 
    # w stands for width, and c stands for the number of channels.
    old_shape = einops.parse_shape(video, 'b t h w c')
    images = einops.rearrange(video, 'b t h w c -> (b t) h w c')
    images = self.resizing_layer(images)
    videos = einops.rearrange(
        images, '(b t) h w c -> b t h w c',
        t = old_shape['t'])
    return videos

# %%
input_shape = (None, 10, HEIGHT, WIDTH, 3)
input = layers.Input(shape=(input_shape[1:]))
x = input

x = Conv2Plus1D(filters=16, kernel_size=(3, 7, 7), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = ResizeVideo(HEIGHT // 2, WIDTH // 2)(x)

# Block 1
x = add_residual_block(x, 16, (3, 3, 3))
x = ResizeVideo(HEIGHT // 4, WIDTH // 4)(x)

# Block 2
x = add_residual_block(x, 32, (3, 3, 3))
x = ResizeVideo(HEIGHT // 8, WIDTH // 8)(x)

# Block 3
x = add_residual_block(x, 64, (3, 3, 3))
x = ResizeVideo(HEIGHT // 16, WIDTH // 16)(x)

# Block 4
x = add_residual_block(x, 128, (3, 3, 3))

x = layers.GlobalAveragePooling3D()(x)
x = layers.Flatten()(x)
x = layers.Dense(10)(x)

model = keras.Model(input, x)
# Out:
# WARNING:tensorflow:From C:\Users\bgre4\venv\lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.0001), 
              metrics = ['accuracy'])

# %%
history = model.fit(x = train_ds,
                    epochs = 50, 
                    validation_data = val_ds)
# Out:
# Epoch 1/50
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
#       1/Unknown 8s 8s/step - accuracy: 0.0000e+00 - loss: 1.9208Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
#       2/Unknown 9s 2s/step - accuracy: 0.1875 - loss: 1.8365    Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
#       3/Unknown 11s 2s/step - accuracy: 0.2083 - loss: 2.2316mirrored_video0.avi
# mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
#       4/Unknown 13s 2s/step - accuracy: 0.2031 - loss: 2.5001mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
#       6/Unknown 16s 2s/step - accuracy: 0.1822 - loss: 2.8731
# C:\Users\bgre4\AppData\Local\Programs\Python\Python310\lib\contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.3649 - loss: 1.1772 - val_accuracy: 0.3261 - val_loss: 1.2484
# Epoch 7/50
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.0000e+00 - loss: 1.5041Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# 2/6 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.0000e+00 - loss: 1.4794 Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# 3/6 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.0000e+00 - loss: 1.4593mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.0078 - loss: 1.4372    mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0971 - loss: 1.3718¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.1298 - loss: 1.3493 - val_accuracy: 0.3261 - val_loss: 1.2450
# Epoch 8/50
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.0000e+00 - loss: 1.4585Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# 2/6 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.0000e+00 - loss: 1.4268 Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# mirrored_video1.avi
# 3/6 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.0000e+00 - loss: 1.3986mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# mirrored_video5.avi
# mirrored_video6.avi
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accurac
━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.5547 - loss: 0.7457mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6174 - loss: 0.6661¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - accuracy: 0.6379 - loss: 0.6385 - val_accuracy: 0.5870 - val_loss: 0.7010
# Epoch 49/50
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.3750 - loss: 0.8105Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# 2/6 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4688 - loss: 0.7830 Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# 3/6 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.5208 - loss: 0.7603mirrored_video0.avi
# mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.5625 - loss: 0.7367mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6304 - loss: 0.6587¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - accuracy: 0.6522 - loss: 0.6316 - val_accuracy: 0.6957 - val_loss: 0.6701
# Epoch 50/50
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.3750 - loss: 0.8054Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# 2/6 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.4688 - loss: 0.7785 Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# 3/6 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.5208 - loss: 0.7555mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - accuracy: 0.5625 - loss: 0.7315mirrored_video4.avi
# mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6304 - loss: 0.6535¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1113-1116.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1188-1191.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1242-1245.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1443-1446.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1653-1656.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1725-1728.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_1950-1953.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2028-2031.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2055-2058.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_2448-2451.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_3522-3525.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_645-648.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_726-729.mov
# ¦е¦-¦¦¦¦¦¦¦¬¦Ж_¦+¦¬¦¬¦-¦-¦-¦¦ (1)_chunk_804-807.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_0-3.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_123-126.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_132-135.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_162-165.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_168-171.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_186-189.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_195-198.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_234-237.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_255-258.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_267-270.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_282-285.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_291-294.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_3-6.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_39-42.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_6-9.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_81-84.mov
# Овечкин,_Романов_и_Ткачак_ТОП_10_силовых_приёмов_НХЛ_сезона_2022_chunk_99-102.mov
# mirrored_video0.avi
# mirrored_video1.avi
# mirrored_video10.avi
# mirrored_video11.avi
# mirrored_video12.avi
# mirrored_video13.avi
# mirrored_video14.avi
# mirrored_video2.avi
# mirrored_video3.avi
# mirrored_video4.avi
# mirrored_video5.avi
# mirrored_video6.avi
# mirrored_video7.avi
# mirrored_video8.avi
# mirrored_video9.avi
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - accuracy: 0.6522 - loss: 0.6265 - val_accuracy: 0.6957 - val_loss: 0.6624

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

plot_history(history)

# %%
model.save('video_model_2.1.keras')
